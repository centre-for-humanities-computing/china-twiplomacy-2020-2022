# %% [markdown]
# # Topics over time

# %%
#### Imports
import gensim
import pandas as pd 
import pickle as pkl 
import altair as alt
import numpy as np 
import os 

import logging
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pandas as pd
#import pyLDAvis.gensim


import matplotlib.dates as md
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager

import re
import pyLDAvis

import matplotlib as mpl
import matplotlib.dates as mdates
import matplotlib.pyplot as plt

from helper_functions import *
# Out:
# /home/coder/.local/share/code-server/extensions/ms-python.python-2020.5.86806/pythonFiles/lib/python/past/types/oldstr.py:36: DeprecationWarning: invalid escape sequence \d
#   """

# %% [markdown]
# ### Early data

# %%
# preparing the data
data_early, diplomats_early, media_early = prep_data('data/early_data.csv')
# Out:
# /home/coder/.local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# loading the model
with open("data/models/earlydataDiplomat.pkl", "rb") as f:
    lda_early = pkl.load(f)
# Out:
# /home/coder/.local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# creating topics over time dataframe for plotting
df_early = topics_over_time(lda_early, diplomats_early)
# Out:
# /home/coder/.local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def plot_subset(df, range, legend_size, figname, figsize = (7.5, 4), dpi = 100): 
    fig, ax = plt.subplots(figsize = figsize, dpi = dpi)
    for topic in range: 
        df_tmp = df[df["topic_id"] == topic].sort_values(by = 'time')
        ax.plot(df_tmp['time'], df_tmp['average_weight'], label = f"Topic {topic}")
    ax.xaxis.set_major_locator(md.MonthLocator(interval = 2))
    ax.xaxis.set_major_formatter(md.DateFormatter('%b %y'))
    ax.set_ylim(bottom = 0, top = 0.4)
    ax.legend(frameon = True, loc = 'upper right', fontsize = legend_size)
    
    fig.savefig(f'plots/{figname}.png', bbox_inches = 'tight')
# Out:
# /home/coder/.local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
plot_subset(df_early, range(1, 8), 8, "topics_over_time_1_7_early")
plot_subset(df_early, range(8, 15), 8, "topics_over_time_8_14_early")
plot_subset(df_early, range(15, 21), 8, "topics_over_time_15_22_early")
# Out:
# /home/coder/.local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Late data

# %%
# preparing the data
data_late, diplomats_late, media_late = prep_data('data/late_data.csv')
# Out:
# /home/coder/.local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# loading the model
with open("data/models/latedataDiplomat.pkl", "rb") as f:
    lda_late = pkl.load(f)
# Out:
# /home/coder/.local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# creating topics over time dataframe for plotting
df_late = topics_over_time(lda_late, diplomats_late)
# Out:
# /home/coder/.local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
plot_subset(df_late, range(1, 8), 8, "topics_over_time_1_7_late")
plot_subset(df_late, range(8, 15), 8, "topics_over_time_8_14_late")
plot_subset(df_late, range(15, 23), 8, "topics_over_time_15_22_late")
plot_subset(df_late, range(23, 31), 8, "topics_over_time_23_30_late")
plot_subset(df_late, range(31, 36), 8, "topics_over_time_31_35_late")
# Out:
# /home/coder/.local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### All data

# %%
# preparing the data
data_all, diplomats_all, media_all = prep_data('data/all_data.csv')
# Out:
# /home/coder/.local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# loading the model
with open("data/models/alldataDiplomat.pkl", "rb") as f:
    lda_all = pkl.load(f)
# Out:
# /home/coder/.local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# creating topics over time dataframe for plotting
df_all = topics_over_time(lda_all, diplomats_all)
# Out:
# /home/coder/.local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
plot_subset(df_all, range(1, 8), 8, "topics_over_time_1_7_all")
plot_subset(df_all, range(8, 15), 8, "topics_over_time_8_14_all")
plot_subset(df_all, range(15, 23), 8, "topics_over_time_15_22_all")
plot_subset(df_all, range(23, 31), 8, "topics_over_time_23_30_all")
# Out:
# /home/coder/.local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
